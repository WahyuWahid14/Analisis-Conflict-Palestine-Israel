# %%
import pandas as pd
import geopandas as gdp

# %%
data = gdp.read_file("C:\\Users\\Wahyu Wahid\\Documents\\Latihan Analisis Bisnis\\conflict_palestin_israel.csv")
data.head()
# data.info()
# Out:
#                                           name date_of_event age  citizenship  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32  Palestinian
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21  Palestinian
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16  Palestinian
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19  Palestinian
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15  Palestinian
#
#       event_location event_location_district event_location_region  \
# 0     Nur Shams R.C.                 Tulkarm             West Bank
# 1     Nur Shams R.C.                 Tulkarm             West Bank
# 2           Kfar Dan                   Jenin             West Bank
# 3  'Aqbat Jaber R.C.                 Jericho             West Bank
# 4         Jenin R.C.                   Jenin             West Bank
#
#   date_of_death gender took_part_in_the_hostilities place_of_residence  \
# ...

# %%
from geopy.geocoders import Nominatim

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="my_geocoder")

# Mendapatkan koordinat dari deskripsi teks
location = geolocator.geocode("indonesia")

# Menampilkan hasil
print((location.latitude, location.longitude))
# Out:
# (-2.4833826, 117.8902853)

# %%
# Inisialisasi geolocator
geolocator = Nominatim(user_agent="my_geocoder")

# Fungsi untuk melakukan geocoding pada setiap baris dataframe
def geocode_row(row):
    location = geolocator.geocode(row['place_of_residence_district'])
    return pd.Series({'Latitude': location.latitude, 'Longitude': location.longitude}) if location else pd.Series({'Latitude': None, 'Longitude': None})

# Menambahkan kolom baru 'Latitude' dan 'Longitude' ke dataframe
data[['Latitude', 'Longitude']] = data.apply(geocode_row, axis=1)

# Menampilkan dataframe hasil geocoding
print(data)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:454, in HTTPConnection.getresponse(self)
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Contoh dataframe
# data = {'ID': [1, 2, 3],
#         'Nama Tempat': ['Eiffel Tower', 'Statue of Liberty', 'Taj Mahal'],
#         'Alamat': ['Paris, France', 'New York, USA', 'Agra, India']}
# df = pd.DataFrame(data)
# print(type(df))

data = pd.read_csv("C:\\Users\\Wahyu Wahid\\Documents\\Latihan Analisis Bisnis\\conflict_palestin_israel.csv")
# print(type(data))
# print(data['place_of_residence_district'])

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="my_geocoder")

# Fungsi untuk melakukan geocoding pada setiap baris dataframe
def geocode_row(row):
    location = geolocator.geocode(row['place_of_residence_district'])
    return pd.Series({'Latitude': location.latitude, 'Longitude': location.longitude}) if location else pd.Series({'Latitude': None, 'Longitude': None})

# Menambahkan kolom baru 'Latitude' dan 'Longitude' ke dataframe
data[['Latitude', 'Longitude']] = data.apply(geocode_row, axis=1)

# Menampilkan dataframe hasil geocoding
print(data)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File c:\Users\Wahyu Wahid\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:635, in HTTPSConnection.connect(self)
#     627     warnings.warn(
# ...
